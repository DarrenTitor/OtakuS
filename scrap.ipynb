# %%
from bs4 import BeautifulSoup
import requests

# %%
html_page = requests.get('https://myanimelist.net/anime/5')

soup = BeautifulSoup(html_page.content, 'html.parser')
content = soup.find('div', id="content")
content.table.tr.td.div.div.a.img.get('data-src')
